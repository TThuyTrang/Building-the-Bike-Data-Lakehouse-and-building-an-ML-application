# %% [markdown]
# #Orchestration Logic
# This notebook programmatically runs all Gold notebooks in sequence.
# It becomes the single entry point for the Gold layer in Databricks Jobs.

# %%
notebooks = [
    "/Workspace/Users/truongthithuytrang140205@gmail.com/Bike_DataLakehouse_BigData_Project/Gold/gold_dim_customers",
    "/Workspace/Users/truongthithuytrang140205@gmail.com/Bike_DataLakehouse_BigData_Project/Gold/gold_dim_products",
    "/Workspace/Users/truongthithuytrang140205@gmail.com/Bike_DataLakehouse_BigData_Project/Gold/gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
