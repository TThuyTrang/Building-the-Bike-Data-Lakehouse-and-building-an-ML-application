# %%
INGESTION_CONFIG = [
    {
        "source": "crm",
        "path": "workspace.bronze.crm_cust_info",
        "table": "crm_cust_info"
    },
    {
        "source": "crm",
        "path": "workspace.bronze.crm_prd_info",
        "table": "crm_prd_info"
    },
    {
        "source": "crm",
        "path": "workspace.bronze.crm_sales_details",
        "table": "crm_sales_details"
    },
    {
        "source": "erp",
        "path": "workspace.bronze.erp_cust_az12",
        "table": "erp_cust_az12"
    },
    {
        "source": "erp",
        "path": "workspace.bronze.erp_loc_a101",
        "table": "erp_loc_a101"
    },
    {
        "source": "erp",
        "path": "workspace.bronze.erp_px_cat_g1v2",
        "table": "erp_px_cat_g1v2"
    }
]

# %%
for item in INGESTION_CONFIG:
    print(f"Ingesting {item['source']} → workspace.bronze.{item['table']}")

    df = spark.table(item["path"])

    (
        df.write
          .mode("overwrite")
          .format("delta")
          .saveAsTable(f"workspace.bronze.{item['table']}")
    )
